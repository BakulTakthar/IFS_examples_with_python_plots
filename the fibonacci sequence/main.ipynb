# %%
import matplotlib.pyplot as plt

lim_arr = []
value_arr = []


def function_for_fibonacci(lim):
    list = [1]
    for i in range(lim):
        number = list[i] + list[i - 1]
        list.append(number)
    return list


plt.plot(function_for_fibonacci(1000))
plt.show()
